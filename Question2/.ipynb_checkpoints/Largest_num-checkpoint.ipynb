# %%
list1 = input("Enter numbers in a list saperate by the space int or float only : ")
list1 = [float(item) for item in list1.split()] 
largest_num = list1[0]
for num in list1:
    if num>largest_num:
        largest_num = num

print(f"The larget number in {list1} : {largest_num}")
# Out:
# Enter numbers in a list saperate by the space int or float only :  12 45 74 54
# The larget number in [12.0, 45.0, 74.0, 54.0] : 74.0

# %%
def lar_num(list1: float) -> float :
    """
    This Function is find the largest number in the input list
    Args:
        list1(list1: list1(float)): This fuction in collecting only int or float type item in the list
    Returs:
        Larget_number : This function is return the larget number to list1
    """
    # VAlidate that input must be a list
    if not isinstance(list1, list):
        raise TypeError("This is take only int or float number")
    #  Validate thet input list is not empty
    if not list1:
        raise ValueError("This fucition take must be one arguments not emplty")
    
    largest_num = list1[0]
    for num in list1:
        if num>largest_num:
            largest_num = num
    
    print(f"The larget number in {list1} : {largest_num}")

if __name__=="__main__":

    try: 
        # Take input from the user
        user = (input("Enter numbers in a list saperate by the space int or float only : "))    
        # convert the input into float and split space
        user = [float(item) for item in list1().split]
        # Calling the function
        print(lar_num(user))

    except (TypeError,ValueError) as e: 
        print(e)
    except Exception as e :
        print(e)
# Out:
# Enter numbers in a list saperate by the space int or float only :  1 2 4
# 'list' object is not callable
