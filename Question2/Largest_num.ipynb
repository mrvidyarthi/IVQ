# %%
def lar_num(list1: list[float]) -> float :
    """
    This Function is find the largest number in the input list
    Args:
        list1(list1: list1(float)): This fuction in collecting only int or float type item in the list
    Returs:
        Larget_number : This function is return the larget number to list1
    """
    # VAlidate that input must be a list
    if not isinstance(list1, list):
        raise TypeError("Error: This is take only list")
    #  Validate thet input list is not empty
    if not list1:
        raise ValueError("Error: This fucition take must be one arguments not emplty")

    for item in list1:
        if not isinstance(item,(int,float)):
            raise TypeError("Error: input must be int or float")
    
    largest_num = list1[0]
    for num in list1:
        if num>largest_num:
            largest_num = num
    
    print(f"The larget number in {list1} : {largest_num}")

    return largest_num

if __name__=="__main__":

    try: 
        # Take input from the user
        user = (input("Enter numbers in a list saperate by the space int or float only : "))    
        # convert the input into float and split space
        user = [float(item) for item in user.split()]
        # Calling the function
        lar_num(user)

    except (TypeError,ValueError) as e: 
        print(e)
    except Exception as e :
        print(e)
# Out:
# Enter numbers in a list saperate by the space int or float only :
# Error: This fucition take must be one arguments not emplty

# %%
list1=input("Enter number in a list seprated by space which are int or float only: ")
list1=[float(item) for item in list1.split()]
largest_num=list1[0]
all_same=True
for item in list1:
    if largest_num < item :
        largest_num = item
    elif largest_num != item:
        all_same = False
if all_same:
    print("All item in {list1} are same")
print(f"The largest number in list {list1} is : {largest_num}")
# Out:
# Enter number in a list seprated by space which are int or float only:  3 4 5 6 7
# The largest number in list [3.0, 4.0, 5.0, 6.0, 7.0] is : 7.0
