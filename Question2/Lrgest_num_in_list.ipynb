# %%
user = input("Enter a number in a list seperated by space int or float: ")
list1=[float(i) for i in user.split()]

largest = list1[0]
all_same = True
for item in list1:
    if item!=largest:
        all_same = False

    if item>largest:
        largest=item
print(all_same)


if all_same :
    print(list1)
    print("None")
else:
    print(largest)
# Out:
# Enter a number in a list seperated by space int or float:  4 4 4 4
# True
# [4.0, 4.0, 4.0, 4.0]
# None

# %%
def larg_num(list1: list) -> list:
    """
    This function is find the largest number in the list item which is take by the user
    Args:
        List Input: This fucntion is take number in a list from the user
    return:
        If user is enter same numbers element in a list then this function is return None other then return largest number
    """
    # Validate given list is list
    if not isinstance(list1,list):
        raise TypeError("TypeError: Take only list.")
    # Validate given list take must be one arguments
    if not list:
        raise ValueError("ValueError: There are must be one arguments in the list")
    # Validate given input must be int or float
    for item in list1:
        if not isinstance(item,(int,float)):
            raise ValueError("ValueError: This function is support int or float item in the list")

    largest = list1[0]
    all_same = True
    for item in list1:
        if item!=largest:
            all_same = False
    
        if item>largest:
            largest=item
    
    if all_same:
        return None
    else :
        return largest


if __name__=="__main__":
    try:
        # Take input from the user
        user = input("Enter a number in a list seperated by space int or float: ")
        # Split space and converting into float take input 
        list1=[float(i) for i in user.split()]
        # calling function
        result=larg_num(list1)
        # Print Largest number
        print(f"the result)
    except TypeError as e:
        print(e)
    except ValueError as e :
        print(e)

    except Exception as e:
        print(e)
# Out:
# Enter a number in a list seperated by space int or float:  88 88 88
# None
